# %%
## 2003-2015 매해 16강 진출한 팀들의 32강 골득실과 
## 16강 골의 상관관계 그래프 & python file

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


for year in range(2003,2019) :
    file_path = './data/In' + str(year)+ '_32_goals_about_top16_team.csv'
    data = pd.read_csv(file_path,encoding = 'euc-kr')
    short_year = year - 2000

    data['all_goals_32' + str(short_year)] = data['home_goal_32_' + str(short_year)] + data['away_goal_32_' + str(short_year)]
    data['all_goals_16' + str(short_year)] = data['home_goal_16_' + str(short_year)] + data['away_goal_16_' + str(short_year)]

    data['all_losts_32' + str(short_year)] = data['home_lost_32_' + str(short_year)] + data['away_lost_32_' + str(short_year)]
    data['all_losts_16' + str(short_year)] = data['home_lost_16_' + str(short_year)] + data['away_lost_16_' + str(short_year)]
    scatter_plot = plt.figure()
    axes1 = scatter_plot.add_subplot(2,2,1) ##2행 2열 
    axes2 = scatter_plot.add_subplot(2,2,2)
    axes3 = scatter_plot.add_subplot(2,2,3)
    axes4 = scatter_plot.add_subplot(2,2,4)

    axes1.scatter(x=data['home_goal_32_' + str(short_year)],y= data['home_goal_16_' + str(short_year)],alpha=0.5)
    axes2.scatter(x=data['away_goal_32_' + str(short_year)],y= data['away_goal_16_' + str(short_year)],alpha=0.5)
    axes3.scatter(x=data['all_goals_32' + str(short_year)] ,y= data['all_goals_16' + str(short_year)] ,alpha=0.5)
    axes4.scatter(x=data['all_losts_32' + str(short_year)] ,y= data['all_losts_16' + str(short_year)] ,alpha=0.5)

    axes1.set_title('32 Hgoals VS 16 Hgoals') 
    axes1.set_xlabel('home_goal_32') 
    axes1.set_ylabel('home_goal_16')

    axes2.set_title('32 Vgoals VS 16 Vgoals') 
    axes2.set_xlabel('away_goal_16') 
    axes2.set_ylabel('away_goal_16')

    axes3.set_title('32 Allgoals VS 16 Allgoals') 
    axes3.set_xlabel('all_goals_32') 
    axes3.set_ylabel('all_goals_16')

    axes4.set_title('32 AllLosts VS 16 AllLosts') 
    axes4.set_xlabel('all_losts_32') 
    axes4.set_ylabel('all_losts_16')
    
    scatter_plot.tight_layout()
    
    save_path = './data/In' +str(year) +'_analysis_about_Goals_top32VStop16.png'
    plt.savefig(save_path)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data03 = pd.read_csv('./data/In2003_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data04 = pd.read_csv('./data/In2004_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data05 = pd.read_csv('./data/In2005_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data06 = pd.read_csv('./data/In2006_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data07 = pd.read_csv('./data/In2007_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data08 = pd.read_csv('./data/In2008_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data09 = pd.read_csv('./data/In2009_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data10 = pd.read_csv('./data/In2010_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data11 = pd.read_csv('./data/In2011_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data12 = pd.read_csv('./data/In2012_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data13 = pd.read_csv('./data/In2013_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data14 = pd.read_csv('./data/In2014_32_goals_about_top16_team.csv',encoding = 'euc-kr')
data15 = pd.read_csv('./data/In2015_32_goals_about_top16_team.csv',encoding = 'euc-kr')
                   
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(2,2,1)                   

axes1.scatter(x=data03['home_goal_32_3'], y= data03['home_goal_16_3'],alpha=0.5)
axes1.scatter(x=data04['home_goal_32_4'], y= data04['home_goal_16_4'],alpha=0.5)
axes1.scatter(x=data05['home_goal_32_5'], y= data05['home_goal_16_5'],alpha=0.5)
axes1.scatter(x=data06['home_goal_32_6'], y= data06['home_goal_16_6'],alpha=0.5)
axes1.scatter(x=data07['home_goal_32_7'], y= data07['home_goal_16_7'],alpha=0.5)
axes1.scatter(x=data08['home_goal_32_8'], y= data08['home_goal_16_8'],alpha=0.5)
axes1.scatter(x=data09['home_goal_32_9'], y= data09['home_goal_16_9'],alpha=0.5)
axes1.scatter(x=data10['home_goal_32_10'],y= data10['home_goal_16_10'],alpha=0.5)
axes1.scatter(x=data11['home_goal_32_11'],y= data11['home_goal_16_11'],alpha=0.5)
axes1.scatter(x=data12['home_goal_32_12'],y= data12['home_goal_16_12'],alpha=0.5)
axes1.scatter(x=data13['home_goal_32_13'],y= data13['home_goal_16_13'],alpha=0.5)
axes1.scatter(x=data14['home_goal_32_14'],y= data14['home_goal_16_14'],alpha=0.5)
axes1.scatter(x=data15['home_goal_32_15'],y= data15['home_goal_16_15'],alpha=0.5)

axes1.set_xlabel('home_goal_32') 
axes1.set_ylabel('home_goal_16')



axes2 = scatter_plot.add_subplot(2,2,2)                   
axes2.scatter(x=data03['away_goal_32_3'], y= data03['away_goal_16_3'],alpha=0.5)
axes2.scatter(x=data04['away_goal_32_4'], y= data04['away_goal_16_4'],alpha=0.5)
axes2.scatter(x=data05['away_goal_32_5'], y= data05['away_goal_16_5'],alpha=0.5)
axes2.scatter(x=data06['away_goal_32_6'], y= data06['away_goal_16_6'],alpha=0.5)
axes2.scatter(x=data07['away_goal_32_7'], y= data07['away_goal_16_7'],alpha=0.5)
axes2.scatter(x=data08['away_goal_32_8'], y= data08['away_goal_16_8'],alpha=0.5)
axes2.scatter(x=data09['away_goal_32_9'], y= data09['away_goal_16_9'],alpha=0.5)
axes2.scatter(x=data10['away_goal_32_10'],y= data10['away_goal_16_10'],alpha=0.5)
axes2.scatter(x=data11['away_goal_32_11'],y= data11['away_goal_16_11'],alpha=0.5)
axes2.scatter(x=data12['away_goal_32_12'],y= data12['away_goal_16_12'],alpha=0.5)
axes2.scatter(x=data13['away_goal_32_13'],y= data13['away_goal_16_13'],alpha=0.5)
axes2.scatter(x=data14['away_goal_32_14'],y= data14['away_goal_16_14'],alpha=0.5)
axes2.scatter(x=data15['away_goal_32_15'],y= data15['away_goal_16_15'],alpha=0.5)
axes2.set_xlabel('away_goal_32') 
axes2.set_ylabel('away_goal_16')


axes3 = scatter_plot.add_subplot(2,2,3)                   
axes3.scatter(x=data03['home_goal_32_3'] + data03['away_goal_32_3'], y= data03['home_goal_16_3'] + data03['away_goal_16_3'],alpha=0.5)
axes3.scatter(x=data04['home_goal_32_4'] + data04['away_goal_32_4'], y= data04['home_goal_16_4'] + data04['away_goal_16_4'],alpha=0.5)
axes3.scatter(x=data05['home_goal_32_5'] + data05['away_goal_32_5'], y= data05['home_goal_16_5'] + data05['away_goal_16_5'],alpha=0.5)
axes3.scatter(x=data06['home_goal_32_6'] + data06['away_goal_32_6'], y= data06['home_goal_16_6'] + data06['away_goal_16_6'],alpha=0.5)
axes3.scatter(x=data07['home_goal_32_7'] + data07['away_goal_32_7'], y= data07['home_goal_16_7'] + data07['away_goal_16_7'],alpha=0.5)
axes3.scatter(x=data08['home_goal_32_8'] + data08['away_goal_32_8'], y= data08['home_goal_16_8'] + data08['away_goal_16_8'],alpha=0.5)
axes3.scatter(x=data09['home_goal_32_9'] + data09['away_goal_32_9'], y= data09['home_goal_16_9'] + data09['away_goal_16_9'],alpha=0.5)
axes3.scatter(x=data10['home_goal_32_10']+ data10['away_goal_32_10'],y= data10['home_goal_16_10']+ data10['away_goal_16_10'],alpha=0.5)
axes3.scatter(x=data11['home_goal_32_11']+ data11['away_goal_32_11'],y= data11['home_goal_16_11']+ data11['away_goal_16_11'],alpha=0.5)
axes3.scatter(x=data12['home_goal_32_12']+ data12['away_goal_32_12'],y= data12['home_goal_16_12']+ data12['away_goal_16_12'],alpha=0.5)
axes3.scatter(x=data13['home_goal_32_13']+ data13['away_goal_32_13'],y= data13['home_goal_16_13']+ data13['away_goal_16_13'],alpha=0.5)
axes3.scatter(x=data14['home_goal_32_14']+ data14['away_goal_32_14'],y= data14['home_goal_16_14']+ data14['away_goal_16_14'],alpha=0.5)
axes3.scatter(x=data15['home_goal_32_15']+ data15['away_goal_32_15'],y= data15['home_goal_16_15']+ data15['away_goal_16_15'],alpha=0.5)
axes3.set_xlabel('ALL_goal_32') 
axes3.set_ylabel('ALL_goal_16')

axes4 = scatter_plot.add_subplot(2,2,4)                   
axes4.scatter(x=data03['home_lost_32_3'] + data03['away_lost_32_3'], y= data03['home_lost_16_3'] + data03['away_lost_16_3'],alpha=0.5)
axes4.scatter(x=data04['home_lost_32_4'] + data04['away_lost_32_4'], y= data04['home_lost_16_4'] + data04['away_lost_16_4'],alpha=0.5)
axes4.scatter(x=data05['home_lost_32_5'] + data05['away_lost_32_5'], y= data05['home_lost_16_5'] + data05['away_lost_16_5'],alpha=0.5)
axes4.scatter(x=data06['home_lost_32_6'] + data06['away_lost_32_6'], y= data06['home_lost_16_6'] + data06['away_lost_16_6'],alpha=0.5)
axes4.scatter(x=data07['home_lost_32_7'] + data07['away_lost_32_7'], y= data07['home_lost_16_7'] + data07['away_lost_16_7'],alpha=0.5)
axes4.scatter(x=data08['home_lost_32_8'] + data08['away_lost_32_8'], y= data08['home_lost_16_8'] + data08['away_lost_16_8'],alpha=0.5)
axes4.scatter(x=data09['home_lost_32_9'] + data09['away_lost_32_9'], y= data09['home_lost_16_9'] + data09['away_lost_16_9'],alpha=0.5)
axes4.scatter(x=data10['home_lost_32_10']+ data10['away_lost_32_10'],y= data10['home_lost_16_10']+ data10['away_lost_16_10'],alpha=0.5)
axes4.scatter(x=data11['home_lost_32_11']+ data11['away_lost_32_11'],y= data11['home_lost_16_11']+ data11['away_lost_16_11'],alpha=0.5)
axes4.scatter(x=data12['home_lost_32_12']+ data12['away_lost_32_12'],y= data12['home_lost_16_12']+ data12['away_lost_16_12'],alpha=0.5)
axes4.scatter(x=data13['home_lost_32_13']+ data13['away_lost_32_13'],y= data13['home_lost_16_13']+ data13['away_lost_16_13'],alpha=0.5)
axes4.scatter(x=data14['home_lost_32_14']+ data14['away_lost_32_14'],y= data14['home_lost_16_14']+ data14['away_lost_16_14'],alpha=0.5)
axes4.scatter(x=data15['home_lost_32_15']+ data15['away_lost_32_15'],y= data15['home_lost_16_15']+ data15['away_lost_16_15'],alpha=0.5)
axes4.set_xlabel('ALL_lost_32') 
axes4.set_ylabel('ALL_lost_16')

scatter_plot.tight_layout()
save_path = './data/ALL_joongbok_analysis_DATA.png'
plt.savefig(save_path)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

scatter_plot = plt.figure()
for year in range(2003,2016) :
    file_path = './data/In' + str(year)+ '_32_goals_about_top16_team.csv'
    data = pd.read_csv(file_path,encoding = 'euc-kr')
    short_year = year - 2000
    print("Year" , year )
    if year == 2003 :
        sum_data_hg32 = data['home_goal_32_' + str(short_year)]
        sum_data_hg16 = data['home_goal_16_' + str(short_year)]

        sum_data_ag32 = data['away_goal_32_' + str(short_year)]
        sum_data_ag16 = data['away_goal_16_' + str(short_year)]

        sum_data_Alg32 = data['home_goal_32_' + str(short_year)] + data['away_goal_32_' + str(short_year)]
        sum_data_Alg16 = data['home_goal_16_' + str(short_year)] + data['away_goal_16_' + str(short_year)]

        sum_data_AlL32 = data['home_lost_32_' + str(short_year)] + data['away_lost_32_' + str(short_year)]
        sum_data_AlL16 = data['home_lost_16_' + str(short_year)] + data['away_lost_16_' + str(short_year)]
        
    else : 
        sum_data_hg32 += data['home_goal_32_' + str(short_year)]
        sum_data_hg16 += data['home_goal_16_' + str(short_year)]

        sum_data_ag32 += data['away_goal_32_' + str(short_year)]
        sum_data_ag16 += data['away_goal_16_' + str(short_year)]

        sum_data_Alg32 += data['home_goal_32_' + str(short_year)] + data['away_goal_32_' + str(short_year)]
        sum_data_Alg16 += data['home_goal_16_' + str(short_year)] + data['away_goal_16_' + str(short_year)]

        sum_data_AlL32 += data['home_lost_32_' + str(short_year)] + data['away_lost_32_' + str(short_year)]
        sum_data_AlL16 += data['home_lost_16_' + str(short_year)] + data['away_lost_16_' + str(short_year)]
  

axes1 = scatter_plot.add_subplot(2,2,1) ##2행 2열 
axes2 = scatter_plot.add_subplot(2,2,2)
axes3 = scatter_plot.add_subplot(2,2,3)
axes4 = scatter_plot.add_subplot(2,2,4)

axes1.scatter(x=sum_data_hg32, y= sum_data_hg16 ,alpha=0.5)
axes2.scatter(x=sum_data_ag32, y= sum_data_ag16 ,alpha=0.5)
axes3.scatter(x=sum_data_Alg32,y= sum_data_Alg16 ,alpha=0.5)
axes4.scatter(x=sum_data_AlL32,y= sum_data_AlL16 ,alpha=0.5)

axes1.set_title('32 Hgoals VS 16 Hgoals') 
axes1.set_xlabel('home_goal_32') 
axes1.set_ylabel('home_goal_16')

axes2.set_title('32 Vgoals VS 16 Vgoals') 
axes2.set_xlabel('away_goal_16') 
axes2.set_ylabel('away_goal_16')

axes3.set_title('32 Allgoals VS 16 Allgoals') 
axes3.set_xlabel('all_goals_32') 
axes3.set_ylabel('all_goals_16')

axes4.set_title('32 AllLosts VS 16 AllLosts') 
axes4.set_xlabel('all_losts_32') 
axes4.set_ylabel('all_losts_16')
scatter_plot.tight_layout()
scatter_plot.tight_layout()
save_path = './data/ALL_count_analysis_DATA.png'
plt.savefig(save_path)
# Out:
# Year 2003
# Year 2004
# Year 2005
# Year 2006
# Year 2007
# Year 2008
# Year 2009
# Year 2010
# Year 2011
# Year 2012
# Year 2013
# Year 2014
# Year 2015
